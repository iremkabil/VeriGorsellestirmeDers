# %% [markdown]
# ## Histogram ve Yoğunluk

# %%
import seaborn as sns
diamonds = sns.load_dataset("diamonds")
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.displot(df.price);

# %%
sns.histplot(df.price, kde=True);
# kde : yoğunluk fonksiyonunun da grafik üzerine koyulup koyulmaması

# %%
# ?sns.histplot
# Out:
# Signature:
# sns.histplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     weights=None,
#     stat='count',
#     bins='auto',
#     binwidth=None,
#     binrange=None,
#     discrete=None,
#     cumulative=False,
#     common_bins=True,
#     common_norm=True,
#     multiple='layer',
#     element='bars',
#     fill=True,
#     shrink=1,
#     kde=False,
#     kde_kws=None,
#     line_kws=None,
#     thresh=0,
#     pthresh=None,
#     pmax=None,
#     cbar=False,
#     cbar_ax=None,
#     cbar_kws=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     color=None,
#     log_scale=None,
#     legend=True,
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Plot univariate or bivariate histograms to show distributions of datasets.
#
# A histogram is a classic visualization tool that represents the distribution
# of one or more variables by counting the number of observations that fall within
# discrete bins.
#
# ...

# %%
sns.histplot(df.price, bins=10);

# %%
sns.histplot(df.price, bins=1000);

# %%
sns.kdeplot(df.price, warn_singular=False);

# %%
# ?sns.kdeplot
# Out:
# Signature:
# sns.kdeplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     weights=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     color=None,
#     fill=None,
#     multiple='layer',
#     common_norm=True,
#     common_grid=False,
#     cumulative=False,
#     bw_method='scott',
#     bw_adjust=1,
#     warn_singular=True,
#     log_scale=None,
#     levels=10,
#     thresh=0.05,
#     gridsize=200,
#     cut=3,
#     clip=None,
#     legend=True,
#     cbar=False,
#     cbar_ax=None,
#     cbar_kws=None,
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Plot univariate or bivariate distributions using kernel density estimation.
#
# A kernel density estimate (KDE) plot is a method for visualizing the
# distribution of observations in a dataset, analogous to a histogram. KDE
# represents the data using a continuous probability density curve in one or
# more dimensions.
#
# ...

# %%
(sns.FacetGrid(df,
              hue = "cut",
              height = 5,
              xlim = (0,1000)));

# %% [markdown]
# * sns.FacetGrid: Bu, Seaborn'un FacetGrid sınıfını kullanarak çoklu grafikleri düzenlemek için kullanılan bir yapıdır. Farklı kategorilere göre veriyi bölüp her birini ayrı bir grafikte gösterebilir veya aynı grafikte farklı renklerle temsil edebilir.
# * df: Bu, üzerinde çalıştığımız Pandas DataFrame'dir. DataFrame, price ve cut sütunlarını içerir.
# * hue="cut": Bu parametre, grafiği renklerle farklı kategorilere (bu durumda "cut" kategorilerine) ayırmak için kullanılır. Farklı cut kategorileri farklı renklerle temsil edilecektir.
# * height=5: Bu, her bir facet'in (grafik) yüksekliğini belirler. Grafik 5 inç yüksekliğinde olacaktır.
# * xlim=(0, 10000): Bu, x-ekseninin sınırlarını 0 ile 10000 arasında ayarlamak için kullanılır.
# ##### .map(sns.kdeplot, "price", fill=True):
# * map metodu, belirtilen fonksiyonu grid üzerindeki her bir subplot için uygular.
#  * sns.kdeplot: Kernel Density Estimate (KDE) plot fonksiyonu.
# * "price": KDE plot'un x ekseninde kullanacağı veri sütunu.
# * fill=True: KDE eğrisi altında kalan alanı gölgelendirir.
# * .add_legend(): Grafiğe bir legend (açıklama) ekler. Bu, hangi rengin hangi "cut" kategorisine karşılık geldiğini gösterir.

# %%
(sns
 .FacetGrid(df,
           hue = "cut",
           height = 5,
           xlim = (0,10000))
 .map(sns.kdeplot,"price",fill = True)
 .add_legend()
);
# eski sürümde fill yerine shade vardı

# %%
sns.catplot(x = "cut", y ="price", hue="color", kind="point", data=df);
